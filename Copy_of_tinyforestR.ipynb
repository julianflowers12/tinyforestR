# %% [markdown]
# <a href="https://colab.research.google.com/github/julianflowers12/tinyforestR/blob/main/Copy_of_tinyforestR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# prompt: a slider using jupyter widgets

library(IRdisplay)

# Create a slider widget
slider <- 5 #@param {type:"slider", min:0, max:100, step:1}

# Print the value of the slider
cat("Slider value:", slider, "\n")
display_html(paste0("<p>The value is ", slider, "</p>"))

# %%
install.packages("pak")
library(pak)
pak("needs")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
#
#
# → Will install 1 package.
#
# → Will download 1 CRAN package (5.47 kB).
#
# + needs   0.0.3 [bld][dl] (5.47 kB)
#
#
#
# ℹ Getting 1 pkg (5.47 kB)
#
# ✔ Got needs 0.0.3 (source) (5.47 kB)
#
# ℹ Building needs 0.0.3
#
# ✔ Built needs 0.0.3 (1.2s)
#
# ✔ Installed needs 0.0.3  (24ms)
#
# ✔ 1 pkg: added 1, dld 1 (5.47 kB) [2.5s]

# %%
library(needs)
pkg_install("julianflowers/tinyforestR")
# Out:
# Load `package:needs` in an interactive session to set auto-load flag
#
#
#
#
# → Will install 1 package.
#
# → The package (0 B) is cached.
#
# + tinyforestR   0.0.0.9000 [bld][cmp] (GitHub: fcdfe0f)
#
# ✔ All system requirements are already installed.
#
#
#
# ℹ No downloads are needed, 1 pkg is cached
#
# ℹ Building tinyforestR 0.0.0.9000
#
# ✔ Built tinyforestR 0.0.0.9000 (30.9s)
#
# ✔ Installed tinyforestR 0.0.0.9000 (github::julianflowers/tinyforestR@fcdfe0f) (47ms)
#
# ✔ 1 pkg + 166 deps: kept 166, added 1 [36.9s]

# %%
library(tinyforestR)
# Out:
# Warning message:
# “replacing previous import ‘data.table::first’ by ‘dplyr::first’ when loading ‘tinyforestR’”
# Warning message:
# “replacing previous import ‘data.table::last’ by ‘dplyr::last’ when loading ‘tinyforestR’”
# Warning message:
# “replacing previous import ‘data.table::between’ by ‘dplyr::between’ when loading ‘tinyforestR’”
# Warning message:
# “replacing previous import ‘janitor::crosstab’ by ‘terra::crosstab’ when loading ‘tinyforestR’”
# Warning message:
# “replacing previous import ‘data.table::shift’ by ‘terra::shift’ when loading ‘tinyforestR’”
# Warning message:
# “replacing previous import ‘dplyr::intersect’ by ‘terra::intersect’ when loading ‘tinyforestR’”
# Warning message:
# “replacing previous import ‘ggmap::inset’ by ‘terra::inset’ when loading ‘tinyforestR’”
# Warning message:
# “replacing previous import ‘glue::trim’ by ‘terra::trim’ when loading ‘tinyforestR’”
# Warning message:
# ...

# %%
pkg_install("julianflowers12/myScrapers")
library(myScrapers)
# Out:
#
#
# → Will install 1 package.
#
# → The package (0 B) is cached.
#
# + myScrapers   0.1.0 [bld][cmp] (GitHub: 8a096d2)
#
#
#
# ℹ No downloads are needed, 1 pkg is cached
#
# ✔ Got myScrapers 0.1.0 (source) (19.18 MB)
#
# ℹ Packaging myScrapers 0.1.0
#
# ✔ Packaged myScrapers 0.1.0 (3.2s)
#
# ℹ Building myScrapers 0.1.0
#
# ✔ Built myScrapers 0.1.0 (2.3s)
#
# ✔ Installed myScrapers 0.1.0 (github::julianflowers12/myScrapers@8a096d2) (27ms)
#
# ✔ 1 pkg: added 1, dld 1 (NA B) [12.8s]

# %%
tfdf <- tinyforestR::get_tf_data()
# Out:
# ...
# ── R CMD build ─────────────────────────────────────────────────────────────────
# * checking for file ‘/tmp/RtmpsrVMhh/remotesa461ea967a/julianflowers-myScrapers-fe46ae9/DESCRIPTION’ ... OK
# * preparing ‘myScrapers’:
# * checking DESCRIPTION meta-information ... OK
# * checking for LF line-endings in source and make files and shell scripts
# * checking for empty or unneeded directories
# Omitted ‘LazyData’ from DESCRIPTION
#   NB: this package now depends on R (>= 3.5.0)
#   WARNING: Added dependency on R >= 3.5.0 because serialized objects in
#   serialize/load version 3 cannot be read in older versions of R.
#   File(s) containing such objects:
#     ‘myScrapers/vignettes/annual-counts_cache/html/unnamed-chunk-1_ad4536896088afdadabfca30f1798fc4.RData’
#     ‘myScrapers/vignettes/annual-counts_cache/html/unnamed-chunk-1_ad4536896088afdadabfca30f1798fc4.rdx’
#     ‘myScrapers/vignettes/topic-models_cache/html/unnamed-chunk-2_f57582de137bcd4d9e8d344775c0ea4e.RData’
# ...

# %%
tfdf$tidy_tf
# Out:
#     tf_id lat       lon
# 1   85    51.77789  -1.469139
# 2   86    51.76914  -1.215472
# 3   87    51.73478  -1.239861
# 4   88    51.50028  -2.600333
# 5   89    55.87525  -4.160222
# 6   90    49.19342  -2.091139
# 7   91    52.63214  -1.174139
# 8   92    52.53544  -1.861139
# 9   93    51.51103  -0.227833
# 10  94    50.82800  -0.298167
# 11  95    52.58206  -2.146194
# 12  96    51.54278  -1.786361
# 13  97    51.55686   0.090750
# 14  98    51.40491  -1.341047
# 15  99    53.53533  -1.167639
# 16  100   53.52600  -1.309611
# 17  132   55.85990  -4.303606
# 18  133   55.86052  -4.308922
# 19  134   55.85292  -4.246042
# 20  135   55.83829  -4.289215
# 21  136   55.97363  -3.226764
# 22  137   55.91561  -3.158599
# 23  138   53.77869  -1.749937
# 24  139   53.40720  -3.026452
# 25  140   51.23356  -2.336654
# 26  141   51.40520  -1.292495
# 27  142   52.76141  -1.221030
# 28  143   52.57791  -2.076385
# 29  144   53.00293  -1.169850
# 30  145   53.00996  -1.197738
# ...

# %%
pak("geojsonio")
needs(mapview, geojsonio)
# Out:
#
#
# ✔ All system requirements are already installed.
#
#
#
# ℹ No downloads are needed
#
# ✔ 1 pkg + 49 deps: kept 50 [1.6s]

# %%
tfdf$tidy_tf |>
  mutate(tf_age = parse_number(as.character(tf_age))) |>
  st_as_sf(coords = c("lon", "lat"), crs = 4326)
# Out:
#     tf_id
# 1   85
# 2   86
# 3   87
# 4   88
# 5   89
# 6   90
# 7   91
# 8   92
# 9   93
# 10  94
# 11  95
# 12  96
# 13  97
# 14  98
# 15  99
# 16  100
# 17  132
# 18  133
# 19  134
# 20  135
# 21  136
# 22  137
# 23  138
# 24  139
# 25  140
# 26  141
# 27  142
# 28  143
# 29  144
# 30  145
# ⋮   ⋮
# 209 412
# 210 414
# 211 417
# 212 418
# 213 425
# 214 430
# 215 431
# 216 433
# 217 434
# 218 435
# 219 439
# 220 443
# 221 444
# 222 453
# 223 454
# 224 455
# 225 457
# 226 458
# 227 460
# 228 466
# 229 467
# 230 468
# 231 485
# 232 486
# 233 530
# 234 531
# 235 532
# 236 571
# 237 574
# 238 596
#     planted_by
# 1   Volunteer Group, Local Residents, Earthwatch\n\n
# 2   Volunteer Group, Landscape contractors\n\n
# 3   Landscape contractors\n\n
# 4   Volunteer Group\n\n
# 5   Landscape contractors\n\n
# 6   School Children\n\n
# 7   School Children\n\n
# 8   Landscape contractors\n\n
# 9   Corporate Employees\n\n
# 10  Landscape contractors\n\n
# ...
